# %% [markdown]
# # Social Network Analysis: Characterization of a Network.

# %% [markdown]
# ## Introduction - Getting to know the network

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import json
from networkx.readwrite import json_graph

# %%
G = nx.Graph()

# %%
G = nx.readwrite.edgelist.read_edgelist("facebook.txt", nodetype = int)

# %%
G.number_of_nodes()
# Out:
# 4039

# %%
G.number_of_edges()
# Out:
# 88234

# %%
print(nx.info(G))
# Out:
# Graph with 4039 nodes and 88234 edges

# %%
pos = nx.kamada_kawai_layout(G)
plt.figure(1, figsize = (12,12)) 
nx.draw(G,pos)
plt.show()
